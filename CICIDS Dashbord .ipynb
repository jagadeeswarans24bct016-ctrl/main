# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadeeswarans24bct016-ctrl/main/blob/main/CICIDS%20Dashbord%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-42ac8ec6-e973-431f-bd49-7702be4b24fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42ac8ec6-e973-431f-bd49-7702be4b24fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"Report5.xlsx")

# %%
data

# %%
df = pd. DataFrame(data)

# %%
df. info()

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df. duplicated()

# %%
df. duplicated().sum()

# %%
df. drop_duplicates()

# %%
df

# %%
df. drop_duplicates(inplace = True)

# %%
df

# %%
df. dropna()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df[' Flow Duration'],df[' Total Fwd Packets'],color="red")
plt.title("'Flow Duration vs  Total Fwd Packets" )
plt.xlabel("'Flow Duration")
plt.ylabel("Total Fwd Packets")
plt.show()

# %%
top_20_ports = df[' Destination Port'].value_counts().nlargest(20)

plt.figure(figsize=(12, 6))
plt.bar(top_20_ports.index.astype(str), top_20_ports.values, color="red")
plt.title("Top 20 Most Used Destination Ports")
plt.xlabel("Destination Port")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.hist(df[' Flow Duration'], bins=50)
plt.title("Histogram of Flow Duration")
plt.xlabel("Flow Duration")
plt.ylabel("Frequency")
plt.show()

# %%
counts = df[' Label'].value_counts()

plt.figure(figsize=(10,10))
plt.pie(counts, labels=counts.index, autopct="%1.1f%%", pctdistance=0.80)

circle = plt.Circle((0,0), 0.70, color='white')
plt.gca().add_artist(circle)

plt.legend(
    [f"{counts.index[i]} = {counts.iloc[i]}" for i in range(len(counts))],
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    fontsize=9
)

plt.title("Label Distribution")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,10))

plt.subplot(2,2,1)
plt.scatter(df[' Flow Duration'], df[' Total Fwd Packets'], color="red")
plt.title("Flow Duration vs Total Fwd Packets")
plt.xlabel("Flow Duration")
plt.ylabel("Total Fwd Packets")

plt.subplot(2,2,2)
plt.hist(df[' Flow Duration'], bins=50, color="blue")
plt.title("Histogram of Flow Duration")
plt.xlabel("Flow Duration")
plt.ylabel("Frequency")

plt.subplot(2,2,3)
top_20_ports = df[' Destination Port'].value_counts().nlargest(20)
plt.bar(top_20_ports.index.astype(str), top_20_ports.values, color="green")
plt.title("Top 20 Most Used Destination Ports")
plt.xlabel("Destination Port")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')

plt.subplot(2,2,4)
counts = df[' Label'].value_counts()

wedges, texts, autotexts = plt.pie(
    counts,
    labels=None,
    autopct="%1.1f%%",
    pctdistance=0.80
)


circle = plt.Circle((0,0), 0.70, color='white')
plt.gca().add_artist(circle)

plt.title("Label Distribution")


plt.legend(
    counts.index,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    fontsize=9
)

plt.tight_layout()
plt.savefig("Report5.png", dpi=300)
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadeeswarans24bct016-ctrl/main/blob/main/dataset_of_IDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "flow_duration": [12345, 5678, 8910, 23456, 34567, 45678],
    "total_fwd_pkts": [10, 50, 5, 100, 8, 12],
    "total_bwd_pkts": [8, 5, 60, 2, 90, 10],
    "flow_bytes_s": [5000, 20000, 15000, 30000, 12000, 7000],
    "protocol": ["TCP", "TCP", "UDP", "TCP", "UDP", "TCP"],
    "label": ["Normal", "DoS", "PortScan", "DoS", "BruteForce", "Normal"]
}

# %%
df
# Out:
#    flow_duration  total_fwd_pkts  total_bwd_pkts  flow_bytes_s protocol  \
# 0          12345              10               8          5000      TCP
# 1           5678              50               5         20000      TCP
# 2           8910               5              60         15000      UDP
# 3          23456             100               2         30000      TCP
# 4          34567               8              90         12000      UDP
# 5          45678              12              10          7000      TCP
#
#         label
# 0      Normal
# 1         DoS
# 2    PortScan
# 3         DoS
# 4  BruteForce
# 5      Normal
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['flow_duration'].plot(kind='hist', bins=20, title='flow_duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(15, 10))

# %%
plt.subplot(2, 2, 1)
df['label'].value_counts().plot(kind='bar')
plt.title("Count of Each Attack Type")
plt.xlabel("Attack Type")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot(2, 2, 2)
df['protocol'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Protocol Distribution")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
plt.subplot(2, 2, 3)
plt.scatter(df['total_fwd_pkts'], df['flow_bytes_s'])
plt.title("Forward Packets vs Flow Bytes")
plt.xlabel("Total Forward Packets")
plt.ylabel("Flow Bytes/s")
# Out:
# Text(0, 0.5, 'Flow Bytes/s')

# %%
plt.tight_layout()
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadeeswarans24bct016-ctrl/main/blob/main/IDS_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
# !git clone https://github.com/jagadeeswarans24bct016-ctrl/main.git
# Out:
# fatal: destination path 'main' already exists and is not an empty directory.

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-c71dd439-edbc-4a1f-be44-b9b07a8f0e2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c71dd439-edbc-4a1f-be44-b9b07a8f0e2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(list(upload.keys())[0])
print(df.head())
# Out:
#    flow_duration  total_fwd_pkts  total_bwd_pkts  flow_bytes_s protocol  \
# 0          12345              10               8          5000      TCP
# 1           5678              50               5         20000      TCP
# 2           8910               5              60         15000      UDP
# 3          23456             100               2         30000      TCP
# 4          34567               8              90         12000      UDP
#
#         label
# 0      Normal
# 1         DoS
# 2    PortScan
# 3         DoS
# 4  BruteForce

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df
# Out:
#    flow_duration  total_fwd_pkts  total_bwd_pkts  flow_bytes_s protocol  \
# 0          12345              10               8          5000      TCP
# 1           5678              50               5         20000      TCP
# 2           8910               5              60         15000      UDP
# 3          23456             100               2         30000      TCP
# 4          34567               8              90         12000      UDP
# 5          45678              12              10          7000      TCP
#
#         label
# 0      Normal
# 1         DoS
# 2    PortScan
# 3         DoS
# 4  BruteForce
# 5      Normal
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_92['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
attacks = df[df["label"] != "Normal"]
attacks
# Out:
#    flow_duration  total_fwd_pkts  total_bwd_pkts  flow_bytes_s protocol  \
# 1           5678              50               5         20000      TCP
# 2           8910               5              60         15000      UDP
# 3          23456             100               2         30000      TCP
# 4          34567               8              90         12000      UDP
#
#         label
# 1         DoS
# 2    PortScan
# 3         DoS
# 4  BruteForce
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_115['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_116['flow_duration'].plot(kind='hist', bins=20, title='flow_duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
attack_count = df["label"].value_counts()
attack_count
# Out:
# label
# Normal        2
# DoS           2
# PortScan      1
# BruteForce    1
# Name: count, dtype: int64

# %%
def detect_attack(row):
    if row["total_fwd_pkts"] > 40:
        return "Possible DoS"
    if row["total_bwd_pkts"] > 50:
        return "Possible PortScan"
    if row["flow_bytes_s"] > 25000:
        return "Possible BruteForce"
    return "Normal"

df["predicted"] = df.apply(detect_attack, axis=1)
df
# Out:
#    flow_duration  total_fwd_pkts  total_bwd_pkts  flow_bytes_s protocol  \
# 0          12345              10               8          5000      TCP
# 1           5678              50               5         20000      TCP
# 2           8910               5              60         15000      UDP
# 3          23456             100               2         30000      TCP
# 4          34567               8              90         12000      UDP
# 5          45678              12              10          7000      TCP
#
#         label          predicted
# 0      Normal             Normal
# 1         DoS       Possible DoS
# 2    PortScan  Possible PortScan
# 3         DoS       Possible DoS
# 4  BruteForce  Possible PortScan
# 5      Normal             Normal
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df
# Out:
#    flow_duration  total_fwd_pkts  total_bwd_pkts  flow_bytes_s protocol  \
# 0          12345              10               8          5000      TCP
# 1           5678              50               5         20000      TCP
# 2           8910               5              60         15000      UDP
# 3          23456             100               2         30000      TCP
# 4          34567               8              90         12000      UDP
# 5          45678              12              10          7000      TCP
#
#         label          predicted
# 0      Normal             Normal
# 1         DoS       Possible DoS
# 2    PortScan  Possible PortScan
# 3         DoS       Possible DoS
# 4  BruteForce  Possible PortScan
# 5      Normal             Normal
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
attacks
# Out:
#    flow_duration  total_fwd_pkts  total_bwd_pkts  flow_bytes_s protocol  \
# 1           5678              50               5         20000      TCP
# 2           8910               5              60         15000      UDP
# 3          23456             100               2         30000      TCP
# 4          34567               8              90         12000      UDP
#
#         label
# 1         DoS
# 2    PortScan
# 3         DoS
# 4  BruteForce
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_188['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_189['flow_duration'].plot(kind='hist', bins=20, title='flow_duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
attacks_count = attacks["label"].value_counts()
attacks_count
# Out:
# label
# DoS           2
# PortScan      1
# BruteForce    1
# Name: count, dtype: int64

# %%
predicted_count = df["predicted"].value_counts()
predicted_count
# Out:
# predicted
# Normal               2
# Possible DoS         2
# Possible PortScan    2
# Name: count, dtype: int64
